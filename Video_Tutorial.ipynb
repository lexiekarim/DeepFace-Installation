# %%
pip install deepface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepface import DeepFace
import cv2 #read image
import matplotlib.pyplot as plt #plot image
# Out:
# WARNING:tensorflow:From C:\Users\hcps-karimam\AppData\Roaming\Python\Python39\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def verify(img1_path, img2_path, model_name = "VGG-Face"):
    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)

    plt.imshow(img1[:, :, ::-1])
    plt.show()
    plt.imshow(img2[:, :, ::-1])
    plt.show()

    result = DeepFace.verify(img1_path, img2_path, model_name = model_name)
    print("result", result)
    
    verification = result.__getitem__("verified")
    
    if verification:
        print ("they are same")
    else:
        print("they are different")

# %%
verify("img1.jpg", "img3.jpg", model_name="Facenet")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\hcps-karimam\OneDrive - Henrico County Public Schools\Documents\12th Grade\1. Capstone\MP2\Video_Tutorial.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hcps-karimam/OneDrive%20-%20Henrico%20County%20Public%20Schools/Documents/12th%20Grade/1.%20Capstone/MP2/Video_Tutorial.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> verify("img1.jpg", "img3.jpg", model_name="Facenet")
#
# c:\Users\hcps-karimam\OneDrive - Henrico County Public Schools\Documents\12th Grade\1. Capstone\MP2\Video_Tutorial.ipynb Cell 5 line 7
#       <a href='vscode-notebook-cell:/c%3A/Users/hcps-karimam/OneDrive%20-%20Henrico%20County%20Public%20Schools/Documents/12th%20Grade/1.%20Capstone/MP2/Video_Tutorial.ipynb#W4sZmlsZQ%3D%3D?line=4'>5</a> plt.imshow(img1[:, :, ::-1])
# ...

# %%
verify("img1.jpg", "img2.jpg", model_name="ArcFace")
# Out:
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: C:\Users\hcps-karimam\.deepface\weights\arcface_weights.h5
# 24-12-20 14:41:35 - 🔗 arcface_weights.h5 will be downloaded from https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5 to C:\Users\hcps-karimam\.deepface\weights\arcface_weights.h5...
# 100%|██████████| 137M/137M [00:04<00:00, 29.7MB/s]
# result {'verified': True, 'distance': 0.369055, 'threshold': 0.68, 'model': 'ArcFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine', 'facial_areas': {'img1': {'x': 32, 'y': 23, 'w': 150, 'h': 150, 'left_eye': (129, 82), 'right_eye': (82, 85)}, 'img2': {'x': 48, 'y': 33, 'w': 109, 'h': 109, 'left_eye': (120, 77), 'right_eye': (80, 75)}}, 'time': 7.16}
# they are same
